# %% [markdown]
# ### Importing the necessary documents

# %%
import pandas as pd
import pandas as pd
import numpy as np
from datetime import datetime
import yfinance as yf
import os

# %% [markdown]
# #### Date from which the data is collected

# %%
START_DATE = "2015-01-01"
END_DATE = "2026-12-31"

# %%
NIFTY_TICKER = "^NSEI"
VIX_TICKER = "INDIAVIX"

# %%
SAVE_PATH = r"E:\fourth_sem\nifty_ml_hybrid\datasets\raw\nifty_vixdaily.csv"

# %%
# ----------------------------------------
# 3. Download Data Function
# ----------------------------------------

def download_data(ticker, start, end):
    """
    Downloads daily stock/index data using yfinance.
    """
    data = yf.download(
        ticker,
        start=start,
        end=end,
        interval="1d",
        auto_adjust=False,
        progress=False
    )
    return data


# ----------------------------------------
# 4. Data Cleaning Function
# ----------------------------------------

def clean_data(df):
    """
    Cleans raw downloaded data:
    - Handles MultiIndex columns
    - Standardizes column names
    - Converts date
    - Removes duplicates
    """
    df = df.copy()

    # Reset index (Date → column)
    df.reset_index(inplace=True)

    # Handle MultiIndex (important for indices)
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.droplevel(1)

    # Standardize column names
    df.columns = [col.lower().replace(" ", "_") for col in df.columns]

    # Convert date column
    df["date"] = pd.to_datetime(df["date"])

    # Sort chronologically
    df = df.sort_values("date")

    # Remove duplicates
    df = df.drop_duplicates(subset="date")

    return df


# ----------------------------------------
# 5. Main Pipeline
# ----------------------------------------

def main():

    # Download NIFTY data
    print("Downloading NIFTY-50 data...")
    nifty = download_data(NIFTY_TICKER, START_DATE, END_DATE)
    nifty = clean_data(nifty)

    # Download VIX data
    print("Downloading India VIX data...")
    vix = download_data(VIX_TICKER, START_DATE, END_DATE)
    vix = clean_data(vix)

    # Keep only VIX closing value
    vix = vix[["date", "close"]].copy()
    vix.rename(columns={"close": "india_vix"}, inplace=True)

    # Merge datasets on date
    merged = pd.merge(nifty, vix, on="date", how="left")

    # Forward fill missing VIX values
    merged["india_vix"] = merged["india_vix"].ffill()

    # Final dataset check
    print("\nFinal Dataset Info:")
    print(merged.info())

    # Ensure directory exists
    os.makedirs(os.path.dirname(SAVE_PATH), exist_ok=True)

    # Save dataset
    merged.to_csv(SAVE_PATH, index=False)

    print(f"\nData successfully saved at: {SAVE_PATH}")


# ----------------------------------------
# 6. Execute Script
# ----------------------------------------

if __name__ == "__main__":
    main()
# Out:
# ...
# $INDIAVIX: possibly delisted; no timezone found
#
# 1 Failed download:
# ['INDIAVIX']: possibly delisted; no timezone found
# ...
#
# Final Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2763 entries, 0 to 2762
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2763 non-null   datetime64[ns]
#  1   adj_close  2763 non-null   float64
#  2   close      2763 non-null   float64
#  3   high       2763 non-null   float64
#  4   low        2763 non-null   float64
#  5   open       2763 non-null   float64
#  6   volume     2763 non-null   int64
#  7   india_vix  0 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 172.8 KB
# None
#
# Data successfully saved at: E:\fourth_sem\nifty_ml_hybrid\datasets\raw\nifty_vixdaily.csv
